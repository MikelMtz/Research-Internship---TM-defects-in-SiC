# %% [markdown]
# This are preliminary calculations with the PCM, where the crystal field was supressed by taking CLIG to infinity and then changing the parameter of the fine structure constant to take also the speed of light to infinity in the spin-orbit coupling part. Therefore, both the relativistic effects of the crystal field, and the spin-orbit coupling effect (relativistic on its own) could be supressed separately.

# %%
import matplotlib.pyplot as plt
import numpy as np 

fig, ax = plt.subplots()

elements = ["V",r'$Cr^{+1}$',"Nb",r'$Mo^{+1}$',"Ta",r'$W^{+1}$',r'$Re^{+2}$']
energy_shifts = [0.0353367217, 0.0603273069, 1.7278410294, 0.1165880066, 2.0186343553,0.1231500588,0.5561377700]

ax.scatter(elements, energy_shifts, marker="o",color='navy')
ax.plot(elements, energy_shifts, color='navy')
plt.yticks(fontsize=12)
ax.set_ylabel("Transition Energies from GS (eV)", fontsize=14)
ax.set_xlabel("TM defects in 4H-SiC", fontsize=14)
plt.title("Crystal Field + Spin-Orbit Coupling contributions", fontsize=14)
plt.show()

fig, ax = plt.subplots()

elements = ["V",r'$Cr^{+1}$',"Nb",r'$Mo^{+1}$',"Ta",r'$W^{+1}$',r'$Re^{+2}$']
energy_shifts = [2.1151297914, 1.7237640247, 1.7278410294, 3.0942325919, 0.8568788149,3.6824694225,3.5680374237]

ax.scatter(elements, energy_shifts, marker="s",color='navy')
ax.plot(elements, energy_shifts, color='navy')
plt.yticks(fontsize=12)
ax.set_ylabel("Transition Energies from GS (eV)", fontsize=14)
ax.set_xlabel("TM defects in 4H-SiC", fontsize=14)
plt.title("Non-Relativistic CF + S-O Coupling contributions", fontsize=14)
plt.show()

#SUPRESSED SO

fig, ax = plt.subplots()

elements = ["V",r'$Cr^{+1}$',"Nb",r'$Mo^{+1}$',"Ta",r'$W^{+1}$',r'$Re^{+2}$']
energy_shifts = [2.1107661316, 1.7326080959, 1.5689129276, 2.5858678818, 2.0186343553, 0.0586184379, 3.0986033436]

ax.scatter(elements, energy_shifts, marker="s",color='navy')
ax.plot(elements, energy_shifts, color='navy')
plt.yticks(fontsize=12)
ax.set_ylabel("Transition Energies from GS (eV)", fontsize=14)
ax.set_xlabel("TM defects in 4H-SiC", fontsize=14)
plt.title("Crystal Field + Suppressed S-O Coupling contributions", fontsize=14)
plt.show()

fig, ax = plt.subplots()

elements = ["V",r'$Cr^{+1}$',"Nb",r'$Mo^{+1}$',"Ta",r'$W^{+1}$',r'$Re^{+2}$']
energy_shifts = [2.1151297914, 1.7237640247, 1.7278410294, 3.0942325919, 0.8568788149, 3.6824694225, 3.5680374237]

ax.scatter(elements, energy_shifts, marker="s",color='navy')
ax.plot(elements, energy_shifts, color='navy')
plt.yticks(fontsize=12)
ax.set_ylabel("Transition Energies from GS (eV)", fontsize=14)
ax.set_xlabel("TM defects in 4H-SiC", fontsize=14)
plt.title("Non-Relativistic CF + Suppressed S-O Coupling contributions", fontsize=14)
plt.show()

# %% [markdown]
# # CF + supressed SO

# %%
V_cf =[-953.36824604, -953.36824604, -953.29067682, -953.29067682, -953.29014099]
V_cf_so=[-953.36824604, -953.36824604, -953.36824604, -953.36824604, -953.29067682,
         -953.29067682, -953.29067682, -953.29067682, -953.29014099, -953.29014099]
V_non_rel_cf = [-946.00033292, -946.00033292, -945.92260333, -945.92260333, -945.92166086]
V_non_rel_cf_so = [-946.00033292, -946.00033292, -946.00033292, -946.00033292, -945.92260333, 
                   -945.92260333, -945.92260333, -945.92260333, -945.92166086, -945.92166086]

x_V=[0, 1, 0, 1, 0.5]
x2_V=[3, 4, 5, 6, 3, 4, 5, 6, 3.5, 5.5]
x3_V=[0, 1, 0, 1, 0.5]
x4_V=[3, 4, 5, 6, 3, 4, 5, 6, 3.5, 5.5]
fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(x_V, V_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[0].scatter(x2_V, V_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
ax[0].set_title("Electronic Structure of V")
ax[0].set_ylabel("Energy (Ev)")
ax[0].set_xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Suppressed SO coupling'])
ax[0].set_ylim(-953.375, -953.285)
ax[0].set_xlim(-2.0, 7.0)

ax[1].scatter(x3_V, V_non_rel_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[1].scatter(x4_V, V_non_rel_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
ax[1].set_title("Electronic Structure of V")
ax[1].set_ylabel("Energy (Ev)")
ax[1].set_xticks([0.5, 4.5], ['Non-Relativistic CF', 'Non-Relativistic CF + Suppressed S-O'])
ax[1].set_ylim(-946.01, -945.92)
ax[1].set_xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Cr_cf =[-1054.19230362, -1054.19230362, -1054.12863145, -1054.12863145, -1054.12609622]
Cr_cf_so =[-1054.19230362, -1054.19230362, -1054.19230362, -1054.19230362, -1054.12863145, -1054.12863145,
           -1054.12863145, -1054.12863145, -1054.12609622, -1054.12609622]
Cr_non_rel_cf = [-1045.23251625, -1045.23251625, -1045.16916909, -1045.16916909, -1045.16670889]
Cr_non_rel_cf_so = [-1045.23251625, -1045.23251625, -1045.23251625, -1045.23251625, -1045.16916909, 
                    -1045.16916909, -1045.16916909, -1045.16916909, -1045.16670889, -1045.16670889]

x_Cr=[0, 1, 0, 1, 0.5]
x2_Cr = [3, 4, 5, 6, 3, 4, 5, 6, 4, 5]
x3_Cr=[0, 1, 0, 1, 0.5]
x4_Cr = [3, 4, 5, 6, 3, 4, 5, 6, 4, 5]

fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(x_Cr, Cr_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[0].scatter(x2_Cr, Cr_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
ax[0].set_title(r'Electronic Structure of $Cr^{+1}$')
ax[0].set_ylabel("Energy (Ev)")
ax[0].set_xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Suppressed SO coupling'])
ax[0].set_ylim(-1054.2, -1054.12)
ax[0].set_xlim(-2.0, 7.0)

ax[1].scatter(x3_Cr, Cr_non_rel_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[1].scatter(x4_Cr, Cr_non_rel_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
ax[1].set_title(r'Electronic Structure of $Cr^{+1}$')
ax[1].set_ylabel("Energy (Ev)")
ax[1].set_xticks([0.5, 4.5], ['Non-Relativistic CF', 'Non-Relativistic CF + Suppressed S-O'])
ax[1].set_ylim(-1045.24, -1045.16)
ax[1].set_xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Nb_cf =[-3823.12233626, -3823.05883928, -3823.05883928, -3823.02997915, -3823.02997915]
Nb_cf_so=[-3823.12233626, -3823.12233626, -3823.05883928, -3823.05883928, -3823.05883928,
          -3823.05883928, -3823.02997915, -3823.02997915, -3823.02997915, -3823.02997915]
Nb_non_rel_cf = [-3707.67101769, -3707.61336120, -3707.61336120, -3707.59440840, -3707.59440840]
Nb_non_rel_cf_so = [-3707.67101769, -3707.67101769, -3707.61336120, -3707.61336120, -3707.61336120, 
                    -3707.61336120, -3707.59440840, -3707.59440840, -3707.59440840, -3707.59440840]

x_Nb=[0.5, 0, 1, 0, 1]
x2_Nb=[4, 5, 3, 4, 5, 6, 3, 4, 5, 6]
x3_Nb=[0.5, 0, 1, 0, 1]
x4_Nb=[4, 5, 3, 4, 5, 6, 3, 4, 5, 6]

fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(x_Nb, Nb_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[0].scatter(x2_Nb, Nb_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
ax[0].set_title("Electronic Structure of Nb")
ax[0].set_ylabel("Energy (Ev)")
ax[0].set_xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Suppressed SO coupling'])
ax[0].set_ylim(-3823.14, -3823.01)
ax[0].set_xlim(-2.0, 7.0)

ax[1].scatter(x3_Nb, Nb_non_rel_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[1].scatter(x4_Nb, Nb_non_rel_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
ax[1].set_title("Electronic Structure of Nb")
ax[1].set_ylabel("Energy (Ev)")
ax[1].set_xticks([0.5, 4.5], ['Non-Relativistic CF', 'Non-Relativistic CF + Suppressed S-O'])
ax[1].set_ylim(-3707.676, -3707.59)
ax[1].set_xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Mo_cf =[-4051.57850115, -4051.57850115, -4051.48347225, -4051.46192538, -4051.46192538]
Mo_cf_so = [-4051.57850115, -4051.57850115, -4051.57850115, -4051.57850115, -4051.48347225,
            -4051.48347225, -4051.46192538, -4051.46192538, -4051.46192538, -4051.46192538]
Mo_non_rel_cf = [-3921.40960896, -3921.40960896, -3921.29589801, -3921.28781148 ,-3921.28781148]
Mo_non_rel_cf_so = [-3921.40960896, -3921.40960896, -3921.40960896, -3921.40960896, -3921.29589801, 
                    -3921.29589801, -3921.28781148, -3921.28781148, -3921.28781148, -3921.28781148]

x_Mo=[0, 1, 0.5, 1, 0]
x2_Mo=[3, 4, 5, 6, 4, 5, 3, 4, 5, 6]
x3_Mo=[0, 1, 0.5, 0, 1]
x4_Mo=[3, 4, 5, 6, 4, 5, 3, 4, 5, 6]

fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(x_Mo, Mo_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[0].scatter(x2_Mo, Mo_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
ax[0].set_title(r'Electronic Structure of $Mo^{+1}$')
ax[0].set_ylabel("Energy (Ev)")
ax[0].set_xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Suppressed SO coupling'])
ax[0].set_ylim(-4051.6, -4051.44)
ax[0].set_xlim(-2.0, 7.0)

ax[1].scatter(x3_Mo, Mo_non_rel_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax[1].scatter(x4_Mo, Mo_non_rel_cf_so, s=900, marker="_", linewidth=2, zorder=3, c='maroon')
ax[1].set_title(r'Electronic Structure of $Mo^{+1}$')
ax[1].set_ylabel("Energy (Ev)")
ax[1].set_xticks([0.5, 4.5], ['Non-Relativistic CF', 'Non-Relativistic CF + Suppressed S-O'])
ax[1].set_ylim(-3921.415, -3921.28)
ax[1].set_xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Ta_cf =[-15596.40834879, -15596.33416535, -15596.33416535, -15596.28131684, -15596.28131684]
Ta_cf_so=[-15596.40834879, -15596.40834879, -15596.33416535, -15596.33416535, -15596.33416535, 
          -15596.33416535, -15596.28131684, -15596.28131684, -15596.28131684, -15596.28131684]
Ta_non_rel_cf = [-13199.40094322, -13199.40094302, -13199.36945350, -13199.35215530, -13199.35215515]
Ta_non_rel_cf_so = [-13199.40094322, -13199.40094322, -13199.40094302, -13199.40094302, -13199.36945350, 
                    -13199.36945350, -13199.35215530, -13199.35215530, -13199.35215515, -13199.35215515] 

x_Ta=[0.5, 0, 1, 0, 1]
x2_Ta=[4, 5, 3, 4, 5, 6, 3, 4, 5, 6]
x3_Ta=[0, 1, 0.5, 0, 1]
x4_Ta=[3, 4, 5, 6, 4, 5, 3, 4, 5, 6]

fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(x_Ta, Ta_cf, s=900, marker="_", linewidth=2, zorder=3, c='navy')
ax[0].scatter(x2_Ta, Ta_cf_so, s=900, marker="_", linewidth=2, zorder=3, c='maroon')
ax[0].set_title("Electronic Structure of Ta")
ax[0].set_ylabel("Energy (Ev)")
ax[0].set_xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Suppressed SO coupling'])
ax[0].set_ylim(-15596.42, -15596.26)
ax[0].set_xlim(-2.0, 7.0)

ax[1].scatter(x3_Ta, Ta_non_rel_cf, s=900, marker="_", linewidth=2, zorder=3, c='navy')
ax[1].scatter(x4_Ta, Ta_non_rel_cf_so, s=900, marker="_", linewidth=2, zorder=3, c='maroon')
ax[1].set_title("Electronic Structure of Ta")
ax[1].set_ylabel("Energy (Ev)")
ax[1].set_xticks([0.5, 4.5], ['Non-Relativistic CF', 'Non-Relativistic CF + Suppressed S-O'])
ax[1].set_ylim(-13199.42, -13199.35)
ax[1].set_xlim(-2.0, 7.0)
plt.show()
#########################################################################################
W_cf =[-16133.59910159, -16133.59694740, -16133.59694740, -16133.50346228, -16133.50346228]
W_cf_so=[-16133.59910159, -16133.59910159, -16133.59694740, -16133.59694740, -16133.59694740,
         -16133.59694740, -16133.50346228, -16133.50346228, -16133.50346228, -16133.50346228]
W_non_rel_cf = [-13559.10104184, -13559.10104184,-13558.96571359, -13558.96398713, -13558.96398713]
W_non_rel_cf_so = [-13559.10104184, -13559.10104184, -13559.10104184, -13559.10104184, -13558.96571359, 
                   -13558.96571359, -13558.96398713, -13558.96398713, -13558.96398713, -13558.96398713]

x_W=[0.5, 0, 1, 0, 1]
x2_W=[4, 5, 3, 4, 5, 6, 3, 4, 5, 6]
x3_W=[0, 1, 0.5, 0, 1]
x4_W=[3, 4, 5, 6, 4, 5, 3, 4, 5, 6]

fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(x_W, W_cf, s=900, marker="_", linewidth=2, zorder=3, c='navy')
ax[0].scatter(x2_W, W_cf_so, s=900, marker="_", linewidth=2, zorder=3, c='maroon')
ax[0].set_title(r'Electronic Structure of $W^{+1}$')
ax[0].set_ylabel("Energy (Ev)")
ax[0].set_xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Suppressed SO coupling'])
ax[0].set_ylim(-16133.605, -16133.5)
ax[0].set_xlim(-2.0, 7.0)

ax[1].scatter(x3_W, W_non_rel_cf, s=900, marker="_", linewidth=2, zorder=3, c='navy')
ax[1].scatter(x4_W, W_non_rel_cf_so, s=900, marker="_", linewidth=2, zorder=3, c='maroon')
ax[1].set_title(r'Electronic Structure of $W^{+1}$')
ax[1].set_ylabel("Energy (Ev)")
ax[1].set_xticks([0.5, 4.5], ['Non-Relativistic CF', 'Non-Relativistic CF + Suppressed S-O'])
ax[1].set_ylim(-13559.12, -13558.95)
ax[1].set_xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Re_cf =[-16682.06741372, -16682.06741372, -16681.95354215, -16681.93677487, -16681.93677487]
Re_cf_so =[-16682.06741372, -16682.06741372, -16682.06741372, -16682.06741372, -16681.95354215,
           -16681.95354215, -16681.93677487, -16681.93677487, -16681.93677487, -16681.93677487]
Re_non_rel_cf = [-13932.74526193, -13932.74526193, -13932.61413897, -13932.60957515, -13932.60957515]
Re_non_rel_cf_so = [-13932.74526193, -13932.74526193, -13932.74526193, -13932.74526193, -13932.61413897, 
                    -13932.61413897, -13932.60957515, -13932.60957515, -13932.60957515, -13932.60957515]

x_Re=[0, 1, 0.5, 1, 0]
x2_Re=[3, 4, 5, 6, 4, 5, 3, 4, 5, 6]
x3_Re=[0, 1, 0.5, 1, 0]
x4_Re=[3, 4, 5, 6, 4, 5, 3, 4, 5, 6]

fig, ax = plt.subplots(1,2, figsize=(15,5))

ax[0].scatter(x_Re, Re_cf, s=900, marker="_", linewidth=2, zorder=3, c='navy')
ax[0].scatter(x2_Re, Re_cf_so, s=900, marker="_", linewidth=2, zorder=3, c='maroon')
ax[0].set_title(r'Electronic Structure of $Re^{+2}$')
ax[0].set_ylabel("Energy (Ev)")
ax[0].set_xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Suppressed SO coupling'])
ax[0].set_ylim(-16682.1, -16681.91)
ax[0].set_xlim(-2.0, 7.0)

ax[1].scatter(x3_Re, Re_non_rel_cf, s=900, marker="_", linewidth=2, zorder=3, c='navy')
ax[1].scatter(x4_Re, Re_non_rel_cf_so, s=900, marker="_", linewidth=2, zorder=3, c='maroon')
ax[1].set_title(r'Electronic Structure of $Re^{+2}$')
ax[1].set_ylabel("Energy (Ev)")
ax[1].set_xticks([0.5, 4.5], ['Non-Relativistic CF', 'Non-Relativistic CF + Suppressed S-O'])
ax[1].set_ylim(-13932.75, -13932.6)
ax[1].set_xlim(-2.0, 7.0)
plt.show()

# %% [markdown]
# # CF + SO

# %%
V_cf =[-953.36824604, -953.36824604, -953.29067682, -953.29067682, -953.29014099]
V_cf_so=[-953.36890804, -953.36890804, -953.36760944, -953.36760944, -953.29158801, 
         -953.29158801, -953.29029813, -953.29029813, -953.28958309, -953.28958309]
x_V=[0, 1, 0, 1, 0.5]
x2_V=[4, 5, 4, 5, 4, 5, 4, 5, 4, 5]

fig, ax = plt.subplots()

ax.scatter(x_V, V_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax.scatter(x2_V, V_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
plt.title("Electronic Structure of V")
plt.ylabel("Energy (Ev)")
plt.xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Spin-Orbit Coupling'])
plt.ylim(-953.375, -953.285)
plt.xlim(-2.0, 7.0)
plt.show()
##########################################################################################
Cr_cf =[-1054.19230362, -1054.19230362, -1054.12863145, -1054.12863145, -1054.12609622]
Cr_cf_so =[-1054.19345471, -1054.19345471, -1054.19123772, -1054.19123772, -1054.12982406,
           -1054.12982406, -1054.12817287, -1054.12817287, -1054.12527701, -1054.12527701]
x_Cr=[0, 1, 0, 1, 0.5]
x2_Cr = [4, 5, 4, 5, 4, 5, 4, 5, 4, 5]
fig, ax = plt.subplots()

ax.scatter(x_Cr, Cr_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax.scatter(x2_Cr, Cr_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
plt.title(r' Electronic Structure of $Cr^{+1}$')
plt.ylabel("Energy (Ev)")
plt.xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Spin-Orbit Coupling'])
plt.ylim(-1054.2, -1054.12)
plt.xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Nb_cf =[-3823.12237306, -3823.05901080, -3823.05900987, -3823.03745118, -3823.02965830]
Nb_cf_so=[-3823.12237453, -3823.12237453, -3823.05953912, -3823.05953912, -3823.05848972,
          -3823.05848972, -3823.03744191, -3823.03744191, -3823.02965794, -3823.02965794]
x_Nb=[0.5, 0, 1, 0.5, 0.5]
x2_Nb=[4, 5, 4, 5, 4, 5, 4, 5, 4, 5]

fig, ax = plt.subplots()

ax.scatter(x_Nb, Nb_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax.scatter(x2_Nb, Nb_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
plt.title(" Electronic Structure of Nb")
plt.ylabel("Energy (Ev)")
plt.xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Spin-Orbit Coupling'])
plt.ylim(-3823.14, -3823.01)
plt.xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Mo_cf =[-4051.57850115, -4051.57850115, -4051.48347225, -4051.46192538, -4051.46192538]
Mo_cf_so = [-4051.58072487, -4051.58072487, -4051.57644034, -4051.57644034, -4051.48352973, 
            -4051.48352973, -4051.46351961, -4051.46351961, -4051.46011077, -4051.46011077]
x_Mo=[0, 1, 0.5, 1, 0]
x2_Mo=[4, 5, 4, 5, 4, 5, 4, 5, 4, 5]

fig, ax = plt.subplots()

ax.scatter(x_Mo, Mo_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax.scatter(x2_Mo, Mo_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
plt.title(r' Electronic Structure of $Mo^{+1}$')
plt.ylabel("Energy (Ev)")
plt.xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Spin-Orbit Coupling'])
plt.ylim(-4051.6, -4051.44)
plt.xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Ta_cf =[-15596.40831069, -15596.33427648, -15596.33427381, -15596.31206869, -15596.28113403]
Ta_cf_so=[-15596.40832871, -15596.40832871, -15596.33639601, -15596.33639601, -15596.33228647,
          -15596.33228647, -15596.31192033, -15596.31192033, -15596.28113217, -15596.28113217]
x_Ta=[0.5, 0, 1, 0.5, 0.5]
x2_Ta=[4, 5, 4, 5, 4, 5, 4, 5, 4, 5]

fig, ax = plt.subplots()

ax.scatter(x_Ta, Ta_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax.scatter(x2_Ta, Ta_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
plt.title(" Electronic Structure of Ta")
plt.ylabel("Energy (Ev)")
plt.xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Spin-Orbit Coupling'])
plt.ylim(-15596.42, -15596.26)
plt.xlim(-2.0, 7.0)
plt.show()
#########################################################################################
W_cf =[-16133.59910159, -16133.59694740, -16133.59694740, -16133.50346228, -16133.50346228]
W_cf_so=[-16133.60396740, -16133.60396740, -16133.59944172, -16133.59944172, -16133.59052153, 
         -16133.59052153, -16133.51040109, -16133.51040109, -16133.49558920, -16133.49558920]
x_W=[0.5, 0, 1, 0, 1]
x2_W=[4, 5, 4, 5, 4, 5, 4, 5, 4, 5]

fig, ax = plt.subplots()

ax.scatter(x_W, W_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax.scatter(x2_W, W_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
plt.title(r' Electronic Structure of $W^{+1}$')
plt.ylabel("Energy (Ev)")
plt.xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Spin-Orbit Coupling'])
plt.ylim(-16133.61, -16133.48)
plt.xlim(-2.0, 7.0)
plt.show()
#########################################################################################
Re_cf =[-16682.06741372, -16682.06741372, -16681.95354215, -16681.93677487, -16681.93677487]
Re_cf_so =[-16682.07962110, -16682.07962110, -16682.05918341, -16682.05918341, -16681.95896680,
           -16681.95896680, -16681.93570186, -16681.93570186, -16681.92844617, -16681.92844617]
x_Re=[0, 1, 0.5, 1, 0]
x2_Re=[4, 5, 4, 5, 4, 5, 4, 5, 4, 5]

fig, ax = plt.subplots()

ax.scatter(x_Re, Re_cf, s=900, marker="_", linewidth=2, zorder=3, color='navy')
ax.scatter(x2_Re, Re_cf_so, s=900, marker="_", linewidth=2, zorder=3, color='maroon')
plt.title(r' Electronic Structure of $Re^{+2}$')
plt.ylabel("Energy (Ev)")
plt.xticks([0.5, 4.5], ['Crystal Field', 'Crystal Field + Spin-Orbit Coupling'])
plt.ylim( -16682.1, -16681.91)
plt.xlim(-2.0, 7.0)
plt.show()
