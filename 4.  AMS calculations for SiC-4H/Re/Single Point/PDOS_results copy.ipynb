# %% [markdown]
# The following image shows the DOS for the Rhenium defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
