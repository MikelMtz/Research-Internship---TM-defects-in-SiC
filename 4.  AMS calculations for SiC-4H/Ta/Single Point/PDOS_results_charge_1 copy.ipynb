# %% [markdown]
# The following image shows the DOS for the Tantalum defect:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
